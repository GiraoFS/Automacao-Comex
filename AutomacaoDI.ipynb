# %%
#declarar varíaveis (dados do processo)
cambio_usd = 5.5246

#Informações de Abertura:
id_processo = "TESTE"
cnpj_importador = " "
via_transporte = "MARÍTIMA"
doc_chegada_carga = "M"
qtde_comercializada = 51
und_comercializada = "TONELADAS"
valor_unitario = 1725
descricao_cliente = " "
ncm_abertura = " "
especificacao_aplic = 1
#escolher:
#- 1 SOPRO COPOLIMERO
#- 2 SOPRO HONOPOLIMERO
#- 3 SOPRO APM
#- 4 INJEÇÃO GERAL
#- 5 FILME DE ALTO PESO MOLECULAR
#- 6 FILME DE MEDIO PESO MOLECULAR
#- 7 TUBOS DE ALTO PESO MOLECULAR
#- 8 TUBOS DE MEDIO PESO MOLECULAR
#- 9 CHAPAS
#- 10 ROTOMOLDAGEM
#- 11 OUTROS
especificacao_acond = 1
#escolher:
#- 1 SACOS
#- 2 GRANEL
#- 3 OUTROS

#Informações BL:
bl = " "
nome_armador =  " "
bandeira = " "
boxes_list = [(" ", " ", " ", " ", " "), 
              (" ", " ", " ", " ", " "),  
             ] #Tupla no formato CNTR, tipo, lacre, peso bruto, volume em cbm
ncm_bl = " "
presenca_pallets = " "
qtde_pallets = 34
free_time = " "
qtde_volumes = 2040
tipo_embalagem = " "
pais_procedencia = " "
data_emissao = " "
data_embarque = " "

if ncm_bl in ncm_abertura:
    pass
else:
    print("ERRO: Divergência no NCM informado.")



#Informações Invoice
invoice = " "
exp_nome = " "
exp_logradouro = " "
exp_numero = " "
exp_complemento = " "
exp_cidade = " "
exp_estado = " "
exp_pais = " "
dados_exportador = (exp_nome, exp_logradouro, exp_numero, exp_complemento, exp_cidade, exp_estado, exp_pais)

fab_nome = " "
fab_logradouro = " "
fab_numero = " "
fab_complemento = " "
fab_cidade = " "
fab_estado = " "
fab_pais = " "
dados_fabricante = (fab_nome, fab_logradouro, fab_numero, fab_complemento, fab_cidade, fab_estado, fab_pais)

peso_bruto = " "
peso_bruto = peso_bruto.replace(".", ",")
peso_liquido = " "
peso_liquido = peso_liquido.replace(".", ",")
pais_procedencia_inv = " "
pais_origem = fab_pais
pais_aquisicao = exp_pais
cond_pgto = " "
moeda_inv = " "
incoterm = " "
local_condicao = " "
ncm_inv = " "
aplicacao = " " #R - Revenda/C - Consumo
qtde_comercializada_inv = 51
und_comercializada_inv = " "
valor_unitario_inv = 1725
moeda_vmle = "220"
moeda_frete = "220"


if ncm_inv != ncm_bl:
    print("ERRO: Divergência no NCM informado na Invoice.")
else:
    pass

if pais_procedencia_inv != pais_procedencia:
    print("ERRO: Divergência no País de Procedência informado.")
else:
    pass



#Informações Certificado de Origem
cert_origem = " "



#Informações Packing List
packing_list = "S/NR"
peso_bruto_pl = " "
peso_bruto_pl = peso_bruto.replace(".", ",")
peso_liquido_pl = " "
peso_liquido_pl = peso_liquido_pl.replace(".", ",")
qtde_volumes_pl = 2040
tipo_embalagem_pl = " "


if tipo_embalagem_pl != tipo_embalagem:
    print("ERRO: Divergência na Quantidade de Volumes informados no Packing List")
else:
    pass

if qtde_volumes_pl != qtde_volumes:
    print("ERRO: Divergência na Quantidade de Volumes informados no Packing List")
else:
    pass

#Informações CE Mercante
ce_mercante = " "
manifesto = " "
nome_embarcacao = " "
empresa_navegacao = " "
agencia_navegacao = " "
data_operacao = " "
urf_entrada = " "
urf_despacho = " "
data_emissao_ce = " "
local_embarque = " "
recinto = " "
setor = " "

valor_frete = 9939.60
valores_ce_list = [("01a CAPATAZIA/THC/THD", 2580, "BRL", "COLLECT"),
                   ("04a TAXA DO C.E.", 30, "USD", "PREPAID"),
                   ("05a TAXA DO C.E.", 22, "USD", "PREPAID"),
                   ("06a TAXA DO C.E.", 140, "USD", "PREPAID"),
                   ("07a TAXA DO C.E.", 488, "USD", "PREPAID"),
                   ("08a TAXA DO C.E.", 30, "USD", "PREPAID"),
                  ]
collect_brl = 0
collect_usd = 0
prepaid_brl = 0
prepaid_usd = 0

for despesa, valor, moeda, tipo in valores_ce_list:
    if (moeda == "BRL") and (tipo == "COLLECT"):
        collect_brl += valor
    if (moeda == "BRL") and (tipo == "PREPAID"):
        prepaid_brl += valor
    if (moeda == "USD") and (tipo == "COLLECT"):
        collect_usd += valor
    if (moeda == "USD") and (tipo == "PREPAID"):
        prepaid_usd += valor

valor_prepaid = round(((prepaid_brl / cambio_usd) + prepaid_usd + valor_frete), 2)
valor_collect1 = round(((collect_brl / cambio_usd) + collect_usd), 2)
capatazia1 = valores_ce_list[0][1]
outros_collect1 = round((((collect_brl - capatazia1) / cambio_usd) + collect_usd), 2)

valor_cfr1 = round((qtde_comercializada_inv * valor_unitario_inv), 2)
valor_vmle = round((valor_cfr1 - valor_prepaid), 2)

valor_prepaid = str(valor_prepaid).replace(".", ",")
valor_collect = str(valor_collect1).replace(".", ",")
capatazia = float(capatazia1)
capatazia = str(capatazia).replace(".", ",")
outros_collect = str(outros_collect1).replace(".", ",")
valor_cfr = float(valor_cfr1)
valor_cfr = str(valor_cfr).replace(".", ",")
valor_vmle = float(valor_vmle)
valor_vmle = str(valor_vmle).replace(".", ",")

acres_deduc_tipo = " "
acres_deduc_den = " "
acres_deduc_moeda = " "
acres_deduc_den2 = " "
acres_deduc_moeda2 = " "


if data_emissao_ce != data_emissao:
    print("ERRO: Divergência na Data de Emissão.")
else:
    pass


#VARIÁVEIS FIXAS

doc_despacho_bl = "CONHECIMENTO DE CARGA"
doc_despacho_invoice = "FATURA COMERCIAL"
doc_despacho_packing = "ROMANEIO DE CARGA"
doc_despacho_cert_origem = "CERTIFICADO DE ORIGEM"

peap_descricao = {"3901.10.10": "(POLIETILENO LINEAR DE BAIXA DENSIDADE).",
                 "3901.20.29": "(POLIETILENO DE DENSIDADE IGUAL OU SUPERIOR A 0,94).",
                 "3901.90.40": "(POLIETILENO CLORADO).",
                 "3902.20.00": "(POLIISOBUTILENO).",
                 "3903.20.00": "(COPOLIMEROS DE ESTIRENO-ACRILONITRILA).",
                 "3905.30.00": "(POLI (ALCOOL VINILICO)).",
                 "3905.99.20": "(POLI (BUTIRAL DE VNILA)).",
                 "3906.10.00": "(POLI (METACRILATO DE METILA)).",
                 "3912.90.10": "(PROPIONATO DE CELULOSE).",
                 "3912.90.20": "(ACETOBUTANOATO DE CELULOSE).",
                 "3901.10.92": "(POLIETILENO DE BAIXA DENSIDADE SEM CARGA E EM FORMAS PRIMARIAS APRESENTADOS EM GRANULOS).",
                 "3901.30.90": "(COPOLIMERO ETILENO/ACETATO VINILA EM FORMAS PRIMARIAS APRESENTADOS EM GRANULOS).",
                 "3902.10.20": "(POLIMERO DE PROPILENO HOMOPOLIMERO EM FORMAS PRIMARIAS APRESENTADOS EM GRANULOS E SEM CARGA).",
                 "3902.30.00": "(POLIMERO DE PROPILENO COPOLIMERO EM FORMAS PRIMARIAS APRESENTADOS EM GRANULOS).",
                 "3903.30.20": "(POLIMERO DE ESTIRENO COPOLIMERO DE ACRILONITRIBUTADIENOESTIRENO SEM CARGA. EM FORMAS PRIMARIAS).",
                 "3907.61.00": "(PET POLI TEREFTALATO DE ETILENO EM GRAOS, DE VISCOSIDADE IGUAL OU MAIOR A 78ML/G, APRESENTADO EM FORMAS PRIMARIAS (GRANULOS)).",
                 } #dicionario no formato NCM, descrição

peap_desp_auto = {"3901.10.10": "159/2017",
                 "3901.20.29": "159/2017",
                 "3901.90.40": "159/2017",
                 "3902.20.00": "159/2017",
                 "3903.20.00": "159/2017",
                 "3905.30.00": "159/2017",
                 "3905.99.20": "159/2017",
                 "3906.10.00": "159/2017",
                 "3912.90.10": "159/2017",
                 "3912.90.20": "159/2017",
                 "3901.10.92": "197/2017",
                 "3901.30.90": "197/2017",
                 "3902.10.20": "197/2017",
                 "3902.30.00": "197/2017",
                 "3903.30.20": "234/2018",
                 "3907.61.00": "155/2020",
                 } #dicionario no formato NCM, desp. autorizativo


descricao_final = descricao_cliente + peap_descricao[ncm_inv]


if cert_origem != " ":
    docs_instrutivos_list = [(doc_despacho_bl, bl),
                             (doc_despacho_invoice, invoice),
                             (doc_despacho_packing, packing_list),
                             (doc_despacho_cert_origem, cert_origem),                            
                            ]
else:
    docs_instrutivos_list = [(doc_despacho_bl, bl),
                             (doc_despacho_invoice, invoice),
                             (doc_despacho_packing, packing_list),
                            ]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-02f4939b351d> in <module>
#     244
#     245
# --> 246 descricao_final = descricao_cliente + peap_descricao[ncm_inv]
#     247
#     248
#
# KeyError: ' '

# %%
import pyautogui
import time
from selenium import webdriver

#Acessar Siscomex WEB
navegador = webdriver.Chrome()
navegador.maximize_window()
navegador.get("https://www1.siscomex.receita.fazenda.gov.br/siscomexImpweb-7/login_cert.jsp")
#pyautogui.click(x=106, y=64)
pyautogui.click(x=979, y=611)
time.sleep(1.5)
pyautogui.press('down', presses=3) 
pyautogui.press('enter')
time.sleep(5)

#Abrir Nova DI
pyautogui.PAUSE = 0.5
pyautogui.click(x=1192, y=227)
pyautogui.moveTo(x=838, y=328)
pyautogui.moveTo(x=969, y=328)
pyautogui.moveTo(x=1096, y=328)
pyautogui.moveTo(x=1236, y=328)
pyautogui.click(x=1334, y=328)
time.sleep(1.5)
navegador.find_element_by_xpath('//*[@id="TABLE_1"]/tbody/tr/td[1]/select').click()
time.sleep(1.5)


#ABA IMPORTADOR
pyautogui.typewrite('01')
pyautogui.press('enter')
time.sleep(3)
navegador.find_element_by_xpath('//*[@id="idDI"]').click()
pyautogui.write(id_processo)
navegador.find_element_by_xpath('//*[@id="cnpjEstab"]').click()
pyautogui.write(cnpj_importador)
navegador.find_element_by_xpath('//*[@id="salvarDi"]').click()
time.sleep(1.5)
pyautogui.press('enter')
navegador.find_element_by_xpath('//*[@id="TABLE_12"]/tbody/tr/td[3]/a/img').click()


#ABA BASICAS
navegador.find_element_by_xpath('//*[@id="urfDespacho"]').click()
pyautogui.write(urf_despacho)

for documento in docs_instrutivos_list:
    navegador.find_element_by_xpath('//*[@id="selectDocInstrucao"]').click()
    pyautogui.write(documento[0])
    navegador.find_element_by_xpath('//*[@id="idDocInstrucao"]').click()
    pyautogui.write(documento[1])
    navegador.find_element_by_xpath('//*[@id="TABLE_15"]/tbody/tr[2]/td[3]/a[1]/img').click()

#Digitar texto:
navegador.find_element_by_xpath('//*[@id="infoComplementares"]').click()
pyautogui.PAUSE = 0.5
pyautogui.write("PREMIX - {}.\n{}".format(id_processo, ("=" * 67)))
pyautogui.write("\nVALOR ADUANEIRO: BRL {:.2f} \n{}".format((valor_cfr1 + valor_collect1) * cambio_usd, ("=" * 67)))
for despesa, valor, moeda, tipo in valores_ce_list:
    if moeda == "BRL":
        pyautogui.write("\n{} = {} {} # USD {}".format(despesa, moeda, str(round(float(valor), 2)).replace(".", ","), str(round(valor / cambio_usd, 2)).replace(".", ",")))
    if moeda == "USD":
        pyautogui.write("\n{} = BRL {} # {} {}".format(despesa, str(round(valor * cambio_usd, 2)).replace(".", ","), moeda, str(round(float(valor), 2)).replace(".", ","), ))
pyautogui.write("\n{}".format("=" * 67))
pyautogui.write("\nTAXA DE CONVERSAO DO CAMBIO EM USD EM 08/10/2021: {:.4f} \n{}".format(cambio_usd, ("=" * 67)))
pyautogui.write("\n- REPRESENTANTES: \nDESPACHANTE: OZEAS BERNARDO DA SILVA JUNIOR \nCPF: 697.675.724-49 - REG. 4D.0.162 \n- \nAJUDANTE DESPACHANTE: FELIPE SOUZA GIRAO \nCPF: 073.985.194-27 - REG. 4A.0.657 \n{}".format("=" * 67))
if cert_origem != " ":
    pyautogui.write("\n* B/L: {} \n* FATURA: {} \n* PACKING LIST: {} \n* CERTIFICADO DE ORIGEM: {} \n* CE-MERCANTE: {} \n{}".format(bl, invoice, packing_list, cert_origem, ce_mercante, ("=" * 67)))
else:
    pyautogui.write("\n* B/L: {} \n* FATURA: {} \n* PACKING LIST: {} \n* CE-MERCANTE: {} \n{}".format(bl, invoice, packing_list, ce_mercante, ("=" * 67)))
pyautogui.write("\nVALOR DEBITADO EM CONTA CORRENTE TAXA SISCOMEX BRL 154,23. \n{}".format("=" * 67))
for box, tipo, lacre, p_bruto, cubagem in boxes_list:
    pyautogui.write("\nCONTAINER: {}.".format(box))
pyautogui.write("\n{}".format(("=" * 67)))


navegador.find_element_by_xpath('//*[@id="TABLE_16"]/tbody/tr/td[2]/input[1]').click()
time.sleep(1.5)
pyautogui.press('enter')
navegador.find_element_by_xpath('//*[@id="TABLE_16"]/tbody/tr/td[3]/a/img').click()


#ABA Transporte
navegador.find_element_by_xpath('//*[@id="opcaoViaTransporte"]').click()
pyautogui.write(via_transporte)
pyautogui.press('enter')
pyautogui.press('tab', presses=2) #Gambiarra

#ERRO AQUI
#navegador.find_element_by_xpath('//*[@id="docChegadaCarga"]').click()
pyautogui.write(doc_chegada_carga)
time.sleep(2)
navegador.find_element_by_xpath('//*[@id="idDocChegadaCarga"]').click
pyautogui.write(manifesto)
navegador.find_element_by_xpath('//*[@id="nomeEmbarcacao"]').click()
pyautogui.write(nome_embarcacao)
navegador.find_element_by_xpath('//*[@id="nomeTransportador"]').click()
pyautogui.write(empresa_navegacao)
navegador.find_element_by_xpath('//*[@id="bandeiraTransportador"]').click()
pyautogui.write(bandeira)
navegador.find_element_by_xpath('//*[@id="identConhecimentoTranspMarFluLac"]').click()
pyautogui.write(ce_mercante)
navegador.find_element_by_xpath('//*[@id="localEmbarqueConhecimentoTranspMarFluLac"]').click()
pyautogui.write(local_embarque)
navegador.find_element_by_xpath('//*[@id="dataEmbarqueConhecimentoTranspMarFluLac"]').click()
pyautogui.write(data_embarque)
pyautogui.press('enter')
navegador.find_element_by_xpath('//*[@id="TABLE_28"]/tbody/tr/td[2]/input[1]').click()
time.sleep(1.5)
pyautogui.press('enter')
navegador.find_element_by_xpath('//*[@id="TABLE_28"]/tbody/tr/td[3]/a/img').click()


#ABA CARGA
navegador.find_element_by_xpath('//*[@id="paisOrigem"]').click()
pyautogui.write(pais_procedencia)
time.sleep(1.5)
navegador.find_element_by_xpath('//*[@id="pesoBruto"]').click()
time.sleep(1.5)
pyautogui.write(str(peso_bruto))
navegador.find_element_by_xpath('//*[@id="pesoLiquidoDi"]').click()
pyautogui.write(str(peso_liquido))
navegador.find_element_by_xpath('//*[@id="cnpjAgente"]').click()
pyautogui.write(agencia_navegacao)
navegador.find_element_by_xpath('//*[@id="urfEntrada"]').click()
pyautogui.write(urf_entrada)
navegador.find_element_by_xpath('//*[@id="selectEmbalagem"]').click()
pyautogui.write(tipo_embalagem)
navegador.find_element_by_xpath('//*[@id="qtdeEmbalagem"]').click()
pyautogui.write(str(qtde_volumes))
navegador.find_element_by_xpath('//*[@id="TABLE_30"]/tbody/tr/td[2]/a[1]/img').click()
navegador.find_element_by_xpath('//*[@id="recAduaneiro"]').click()
pyautogui.write(recinto)
navegador.find_element_by_xpath('//*[@id="setor"]').click()
pyautogui.press('down')
pyautogui.press('enter')
navegador.find_element_by_xpath('//*[@id="armazem"]').click() #Digita Armazém - PAREI AQUI
pyautogui.write(setor)
navegador.find_element_by_xpath('//*[@id="TABLE_32"]/tbody/tr[2]/td/a[1]/img').click()
navegador.find_element_by_xpath('//*[@id="codMoeda"]').click()
pyautogui.write(moeda_vmle)
navegador.find_element_by_xpath('//*[@id="valor"]').click()
pyautogui.write(valor_vmle)
#pyautogui.write(valor_vmle)
navegador.find_element_by_xpath('//*[@id="codMoedaFrete"]').click()
pyautogui.write(moeda_frete)
navegador.find_element_by_xpath('//*[@id="collect"]').click()
pyautogui.write(valor_collect)
#pyautogui.write("1000")
navegador.find_element_by_xpath('//*[@id="prepaid"]').click()
pyautogui.write(valor_prepaid)
#pyautogui.write("1000")
navegador.find_element_by_xpath('//*[@id="TABLE_38"]/tbody/tr/td[2]/input[1]').click()
time.sleep(1.5)
pyautogui.press('enter')
navegador.find_element_by_xpath('//*[@id="TABLE_38"]/tbody/tr/td[3]/a/img').click()


#ABA ADIÇÕES
navegador.find_element_by_xpath('//*[@id="btnIncAdicao"]').click()

#ABA ADIÇÕES - Fornecedor
navegador.find_element_by_xpath('//*[@id="tipoProdutor"]').click()
pyautogui.press('down')
pyautogui.press('enter')

#Rola FOR aqui
navegador.find_element_by_xpath('//*[@id="paisAquisicaoProdNaoExportador"]').click() #país de aquisição
pyautogui.write(pais_aquisicao)
navegador.find_element_by_xpath('//*[@id="nomeExportador"]').click() #nome exportador
pyautogui.write(exp_nome)
navegador.find_element_by_xpath('//*[@id="logradouroExportador"]').click() #logradouro exportador
pyautogui.write(exp_logradouro)
navegador.find_element_by_xpath('//*[@id="numLogradouroExportador"]').click() #numero exportador
pyautogui.write(exp_numero)
navegador.find_element_by_xpath('//*[@id="complLogradouroExportador"]').click() #complemento exportador
pyautogui.write(exp_complemento)
navegador.find_element_by_xpath('//*[@id="cidadeLogradouroExportador"]').click() #cidade exportador
pyautogui.write(exp_cidade)
navegador.find_element_by_xpath('//*[@id="estadoExportador"]').click() #estado exportador
pyautogui.write(exp_estado)
#Encerra FOR aqui

#Outro FOR aqui
navegador.find_element_by_xpath('//*[@id="paisOrigemProdNaoExportador"]').click() #país de origem
pyautogui.write(pais_origem)
navegador.find_element_by_xpath('//*[@id="nomeFabricante"]').click() #nome fabricante
pyautogui.write(fab_nome)
navegador.find_element_by_xpath('//*[@id="logradouroFabricante"]').click() #logradouro fabricante
pyautogui.write(fab_logradouro)
navegador.find_element_by_xpath('//*[@id="numLogradouroFabricante"]').click() #numero fabricante
pyautogui.write(fab_numero)
navegador.find_element_by_xpath('//*[@id="complLogradouroFabricante"]').click() #complemento fabricante
pyautogui.write(fab_complemento)
navegador.find_element_by_xpath('//*[@id="cidadeLogradouroFabricante"]').click() #cidade fabricante
pyautogui.write(fab_cidade)
navegador.find_element_by_xpath('//*[@id="estadoFabricante"]').click() #estado fabricante
pyautogui.write(fab_estado)
#Encerra FOR aqui

navegador.find_element_by_xpath('//*[@id="tipoCobertura"]').click()
pyautogui.press('down')
pyautogui.press('enter')
navegador.find_element_by_xpath('//*[@id="save1"]').click()
time.sleep(1.5)
pyautogui.press('enter')
navegador.find_element_by_xpath('//*[@id="TABLE_9"]/tbody/tr/td[3]/a/img').click()


#ABA ADIÇÕES - Mercadoria
navegador.find_element_by_xpath('//*[@id="codigoNcm"]').click()
pyautogui.write(ncm_inv)
navegador.find_element_by_xpath('//*[@id="pesoLiquido"]').click() 
pyautogui.write(str(peso_liquido))
navegador.find_element_by_xpath('//*[@id="aplicacaoNCM"]').click()
pyautogui.write(aplicacao)
pyautogui.press('enter')
navegador.find_element_by_xpath('//*[@id="qtdMedidaEstatistica"]').click()
pyautogui.write(str(peso_liquido))
navegador.find_element_by_xpath('//*[@id="unMercadoria"]').click() 
pyautogui.write(und_comercializada)
navegador.find_element_by_xpath('//*[@id="vlMercadoria"]').click() 
pyautogui.write(str(valor_unitario))
navegador.find_element_by_xpath('//*[@id="qtMercadoria"]').click() 
pyautogui.write(str(qtde_comercializada).replace(".", ","))
navegador.find_element_by_xpath('//*[@id="especificacaoMercadoria"]').click()
pyautogui.write(descricao_final)
navegador.find_element_by_xpath('//*[@id="btnIncluirAlterarProduto"]').click()

if especificacao_aplic > 0:
    navegador.find_element_by_xpath('//*[@id="nivelNomenclatura"]').click() 
    pyautogui.press('down')
    pyautogui.press('enter')
    navegador.find_element_by_xpath('//*[@id="atributoNomenclatura"]').click() 
    pyautogui.write('aplicacao')
    navegador.find_element_by_xpath('//*[@id="especificacaoNomenclatura"]').click()
    pyautogui.press('down', presses=especificacao_aplic)
    navegador.find_element_by_xpath('//*[@id="TABLE_13"]/tbody/tr[1]/td/a[1]/img').click()
else:
    pass

if especificacao_acond > 0:
    navegador.find_element_by_xpath('//*[@id="nivelNomenclatura"]').click() 
    pyautogui.press('down')
    pyautogui.press('enter')
    navegador.find_element_by_xpath('//*[@id="atributoNomenclatura"]').click() 
    pyautogui.write('acondicionamento')
    navegador.find_element_by_xpath('//*[@id="especificacaoNomenclatura"]').click() 
    pyautogui.press('down', presses=especificacao_acond)
    navegador.find_element_by_xpath('//*[@id="TABLE_13"]/tbody/tr[1]/td/a[1]/img').click()
else:
    pass
    
navegador.find_element_by_xpath('//*[@id="save2"]').click()
time.sleep(1.5)
pyautogui.press('enter')
navegador.find_element_by_xpath('//*[@id="TABLE_24"]/tbody/tr/td[3]/a/img').click() 

#ABA ADIÇÕES - Valor Aduaneiro
navegador.find_element_by_xpath('//*[@id="incoterm"]').click()
pyautogui.write(incoterm)
time.sleep(0.5)
pyautogui.press('enter')
navegador.find_element_by_xpath('//*[@id="localCondicao"]').click() 
pyautogui.write(local_condicao)
navegador.find_element_by_xpath('//*[@id="valorAduaneiroTipoAD"]').click() 
pyautogui.write(acres_deduc_tipo)
navegador.find_element_by_xpath('//*[@id="valorAduaneiroDenominacaoAD"]').click() 
pyautogui.write(acres_deduc_den)
pyautogui.press('enter')
navegador.find_element_by_xpath('//*[@id="codMoedaAD"]').click() 
pyautogui.write(acres_deduc_moeda)
navegador.find_element_by_xpath('//*[@id="valorMoedaAD"]').click() 
pyautogui.write(str(capatazia))
navegador.find_element_by_xpath('//*[@id="btnIncluir"]/img').click()

if outros_collect1 > 0:
    navegador.find_element_by_xpath('//*[@id="valorAduaneiroTipoAD"]').click()
    pyautogui.write(acres_deduc_tipo)
    navegador.find_element_by_xpath('//*[@id="valorAduaneiroDenominacaoAD"]').click()
    pyautogui.write(acres_deduc_den2)
    pyautogui.press('enter')
    navegador.find_element_by_xpath('//*[@id="codMoedaAD"]').click() 
    pyautogui.write(acres_deduc_moeda2)
    navegador.find_element_by_xpath('//*[@id="valorMoedaAD"]').click() 
    pyautogui.write(outros_collect)
    navegador.find_element_by_xpath('//*[@id="btnIncluir"]/img').click()
else:
    pass

navegador.find_element_by_xpath('//*[@id="save3"]').click() 
time.sleep(1.5)
pyautogui.press('enter')
time.sleep(1.5)
navegador.find_element_by_xpath('//*[@id="TABLE_31"]/tbody/tr/td[3]/a/img').click()

if pais_origem == "EGITO" and ncm_inv == "3901.20.29":
    navegador.find_element_by_xpath('//*[@id="tipoAcordo"]').click()
    pyautogui.write('SGPC')
    time.sleep(0.5)
    pyautogui.press('enter')
    time.sleep(0.5)
    pyautogui.press('enter')
    navegador.find_element_by_xpath('//*[@id="tipoAtoLegalII"]').click()
    pyautogui.write('DECRETO')
    navegador.find_element_by_xpath('//*[@id="orgaoEmissorII"]').click()
    pyautogui.write('EXEC')
    navegador.find_element_by_xpath('//*[@id="nrAtoLegalII"]').click()
    pyautogui.write('9229')
    navegador.find_element_by_xpath('//*[@id="anoAtoLegalII"]').click()
    pyautogui.write('2017')
    navegador.find_element_by_xpath('//*[@id="acordo"]').click()
    pyautogui.write('0,00')
else:
    pass

navegador.find_element_by_xpath('//*[@id="save4"]').click()
time.sleep(1)
pyautogui.press('enter')
navegador.find_element_by_xpath('//*[@id="btnAnalisarAdicao"]').click()
# Out:
# ---------------------------------------------------------------------------
# UnexpectedAlertPresentException           Traceback (most recent call last)
# <ipython-input-8-1c4f51c3df04> in <module>
#      42
#      43 #ABA BASICAS
# ---> 44 navegador.find_element_by_xpath('//*[@id="urfDespacho"]').click()
#      45 pyautogui.write(urf_despacho)
#      46
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
# ...
